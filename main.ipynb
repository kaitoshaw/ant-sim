# %% [markdown]
# ## Version 1: Environment Creaetion
# In this section, the code will focus in the development of the environment of the ants. This will include the **Ants** itself, **Ant Base**, **Food Source**, and **Obstacle**. However, the obstacle will be developed in the later after the formulation of the brain and Intelligence of the **Ants**.

# %%
# Version 1.0 Final Version of Brainless Ant

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.update_position()

    def update_position(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        if self.x < 0:
            self.x = self.canvas.winfo_width()
        elif self.x > self.canvas.winfo_width():
            self.x = 0
        if self.y < 0:
            self.y = self.canvas.winfo_height()
        elif self.y > self.canvas.winfo_height():
            self.y = 0
        self.direction += random.uniform(-0.1, 0.1)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.update_position)


# example usage
root = tk.Tk()
canvas = tk.Canvas(root, width=500, height=500)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, x=random.uniform(0, canvas.winfo_width()), y=random.uniform(0, canvas.winfo_height()))
    ants.append(ant)

# print(canvas.winfo_width())
root.mainloop()

# %%
# Version 1.1 Add Brain section to ant

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        if self.x < 0:
            self.x = self.canvas.winfo_width()
        elif self.x > self.canvas.winfo_width():
            self.x = 0
        if self.y < 0:
            self.y = self.canvas.winfo_height()
        elif self.y > self.canvas.winfo_height():
            self.y = 0
        self.direction += random.uniform(-0.1, 0.1)
        
        self.update_position()

    def update_position(self):
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.ant_brain)

# example usage
root = tk.Tk()
canvas = tk.Canvas(root, width=500, height=500)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, x=random.uniform(0, canvas.winfo_width()), y=random.uniform(0, canvas.winfo_height()))
    ants.append(ant)

# print(canvas.winfo_width())
root.mainloop()

# %%
# Version 1.2 Add Concrete walls on the window

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # check if the ant is outside the boundaries of the canvas
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > self.canvas.winfo_width() - self.size:
            self.direction = random.uniform(3*math.pi/2, 5*math.pi/2)
            self.x = self.canvas.winfo_width() - self.size
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > self.canvas.winfo_height() - self.size:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = self.canvas.winfo_height() - self.size
        self.direction += random.uniform(-0.1, 0.1)
        
        self.update_position()

    def update_position(self):
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.ant_brain)

# example usage
root = tk.Tk()
canvas = tk.Canvas(root, width=500, height=500)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, x=random.uniform(0, canvas.winfo_width()), y=random.uniform(0, canvas.winfo_height()))
    ants.append(ant)

root.mainloop()

# %%
# Version 1.3 Set the starting position of the Ant

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        
        # check if the ant is outside the boundaries of the canvas
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(3*math.pi/2, 5*math.pi/2)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        self.update_position()

    def update_position(self):
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.ant_brain)
        

# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, 250, 250)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.4 Add has food attribute to ant

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'red'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food area checking
        if self.x > 250 and self.y > 250:
            self.food = True
            self.color = 'red'
        else:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.5 Add ant base to the canvas

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'red'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food area checking
        if self.x > 250 and self.y > 250:
            self.food = True
            self.color = 'red'
        else:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.square_coords = (x, y, x + size, y + size)
        self.value = value
        self.square = self.canvas.create_rectangle(*self.square_coords, fill='white')
        self.text = self.canvas.create_text(x + size/2, y + size/2, text=str(value))

    def update_value(self, new_value):
        self.value = new_value
        self.canvas.itemconfig(self.text, text=str(self.value))
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.6 Color changing based on AntBase or Food Source

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food area checking
        if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
            self.food = True
            self.color = 'red'
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))
        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self, _ant):
        self.value -= 1
        self.canvas.itemconfig(self.text, text=str(self.value))
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 100)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.7 Counter, off from the canvas

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        self.counter = 0
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food Source
        if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
            self.food = True
            self.color = 'red'
            
        # Base
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            if self.food == True:
                self.counter +=1 
                self.food = False
                self.color = 'black'
        
                print(self.counter)
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))
        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self, _ant):
        self.value -= 1
        self.canvas.itemconfig(self.text, text=str(self.value))
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 100)

ants = []
for i in range(20):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.8 Counter on canvas

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food Source
        if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
            if self.food == False:
                self.food = True
                self.color = 'red'
                food1.update_value()
            
        # Base
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            if self.food == True:
                base1.update_value()

                self.food = False
                self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(1, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        # print('hi')
        self.value += 1 
        print(self.value)
        self.canvas.itemconfig(self.text, text=str(self.value))
        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self):
        self.value -= 1
        self.canvas.itemconfig(self.text, text=str(self.value))
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 100)

ants = []
for i in range(30):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.9 Counter Limitation

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food Source
        if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
            if self.food == False:
                if food1.check_value() > 0:
                    self.food = True
                    self.color = 'red'
                    food1.update_value()
            
        # Base
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            if self.food == True:
                base1.update_value()
                self.food = False
                self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(1, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))
        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self):
        self.value -= 1
        self.canvas.itemconfig(self.text, text=str(self.value))

    def check_value(self):
        return self.value
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 10)

ants = []
for i in range(30):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %% [markdown]
# ## Version 2: Development of Ant Brains
# Rather than using random values of **sin** and **cos** values, there will be changes in the way of thinking. This will be further analysed in the latter.
#
# Fact is, ants do know where their bases are located at. The ants needs to know where their base is to know where to go next

# %%
# Version 2.0 Beginning of Ants returning to base

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        # Returning to base 
        if self.food == True:
            dx = self.speed * math.sin(self.direction)
            dy = self.speed * math.sin(self.direction)
            self.x += dx
            self.y += dy
            self.direction += random.uniform(-0.1, 0.1)


        else:
            dx = self.speed * math.cos(self.direction)
            dy = self.speed * math.sin(self.direction)
            self.x += dx
            self.y += dy
            self.direction += random.uniform(-0.1, 0.1)

            # Food Source
            if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
                if self.food == False:
                    # Food is still available
                    if food1.check_value() > 0:
                        self.food = True
                        self.color = 'red'
                        food1.update_value()

            
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
            
        
        # Base
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            if self.food == True:
                base1.update_value()
                self.food = False
                self.color = 'black'
            
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))

    def get_location(self):
        return self.x, self.y

        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self):
        self.value -= 1
        self.canvas.itemconfig(self.text, text=str(self.value))

    def check_value(self):
        return self.value
    
    def check_location(self):
        return self.x0, self.x1, self.y0, self.y1
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 10)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 2.1 Ants movement still sloppy but returned to base

import tkinter as tk
import random
import math

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        # Returning to base 
        if self.food == True:
            x_rate = random.uniform(math.pi, 2*math.pi)
            y_rate = random.uniform(math.pi/2, 3*math.pi/2)
            dx = self.speed * math.sin(x_rate)
            dy = self.speed * math.cos(y_rate)
            self.x += dx
            self.y += dy

        else:
            dx = self.speed * math.cos(self.direction)
            dy = self.speed * math.sin(self.direction)
            self.x += dx
            self.y += dy
            self.direction += random.uniform(-0.1, 0.1)

            # Food Source
            if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
                if self.food == False:
                    # Food is still available
                    if food1.check_value() > 0:
                        self.food = True
                        self.color = 'red'
                        food1.update_value()

            
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
            
        
        # Base
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            if self.food == True:
                base1.update_value()
                self.food = False
                self.color = 'black'
            
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))

    def get_location(self):
        return self.x, self.y

        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self):
        self.value -= 1
        self.canvas.itemconfig(self.text, text=str(self.value))

    def check_value(self):
        return self.value
    
    def check_location(self):
        return self.x0, self.x1, self.y0, self.y1
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 10)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
target = 200

current = 400

import random
import math

# options = []
# for _ in range(2):
#     a = random.uniform(-0.1, 0)
#     print(math.sin(a)*-1, a)

mult = 0
for i in range(100):
    mult += 0.1
    print(math.cos(mult), mult)
# Out:
# 0.9950041652780258 0.1
# 0.9800665778412416 0.2
# 0.955336489125606 0.30000000000000004
# 0.9210609940028851 0.4
# 0.8775825618903728 0.5
# 0.8253356149096783 0.6
# 0.7648421872844885 0.7
# 0.6967067093471655 0.7999999999999999
# 0.6216099682706645 0.8999999999999999
# 0.5403023058681398 0.9999999999999999
