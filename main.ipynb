# %%
# Version 1.0 Final Version of Brainless Ant

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.update_position()

    def update_position(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        if self.x < 0:
            self.x = self.canvas.winfo_width()
        elif self.x > self.canvas.winfo_width():
            self.x = 0
        if self.y < 0:
            self.y = self.canvas.winfo_height()
        elif self.y > self.canvas.winfo_height():
            self.y = 0
        self.direction += random.uniform(-0.1, 0.1)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.update_position)


# example usage
root = tk.Tk()
canvas = tk.Canvas(root, width=500, height=500)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, x=random.uniform(0, canvas.winfo_width()), y=random.uniform(0, canvas.winfo_height()))
    ants.append(ant)

# print(canvas.winfo_width())
root.mainloop()

# %%
# Version 1.1 Add Brain section to ant

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        if self.x < 0:
            self.x = self.canvas.winfo_width()
        elif self.x > self.canvas.winfo_width():
            self.x = 0
        if self.y < 0:
            self.y = self.canvas.winfo_height()
        elif self.y > self.canvas.winfo_height():
            self.y = 0
        self.direction += random.uniform(-0.1, 0.1)
        
        self.update_position()

    def update_position(self):
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.ant_brain)

# example usage
root = tk.Tk()
canvas = tk.Canvas(root, width=500, height=500)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, x=random.uniform(0, canvas.winfo_width()), y=random.uniform(0, canvas.winfo_height()))
    ants.append(ant)

# print(canvas.winfo_width())
root.mainloop()

# %%
# Version 1.2 Add Concrete walls on the window

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # check if the ant is outside the boundaries of the canvas
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > self.canvas.winfo_width() - self.size:
            self.direction = random.uniform(3*math.pi/2, 5*math.pi/2)
            self.x = self.canvas.winfo_width() - self.size
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > self.canvas.winfo_height() - self.size:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = self.canvas.winfo_height() - self.size
        self.direction += random.uniform(-0.1, 0.1)
        
        self.update_position()

    def update_position(self):
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.ant_brain)

# example usage
root = tk.Tk()
canvas = tk.Canvas(root, width=500, height=500)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, x=random.uniform(0, canvas.winfo_width()), y=random.uniform(0, canvas.winfo_height()))
    ants.append(ant)

root.mainloop()

# %%
# Version 1.3 Set the starting position of the Ant

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='black'
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        
        # check if the ant is outside the boundaries of the canvas
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(3*math.pi/2, 5*math.pi/2)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        self.update_position()

    def update_position(self):
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        self.canvas.after(10, self.ant_brain)
        

# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, 250, 250)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.4 Add has food attribute to ant

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'red'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food area checking
        if self.x > 250 and self.y > 250:
            self.food = True
            self.color = 'red'
        else:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.5 Add ant base to the canvas

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'red'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food area checking
        if self.x > 250 and self.y > 250:
            self.food = True
            self.color = 'red'
        else:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.square_coords = (x, y, x + size, y + size)
        self.value = value
        self.square = self.canvas.create_rectangle(*self.square_coords, fill='white')
        self.text = self.canvas.create_text(x + size/2, y + size/2, text=str(value))

    def update_value(self, new_value):
        self.value = new_value
        self.canvas.itemconfig(self.text, text=str(self.value))
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.6 Color changing based on AntBase or Food Source

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain()
        
    def ant_brain(self):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # Food area checking
        if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
            self.food = True
            self.color = 'red'
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain)
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))
        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 100)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()

# %%
# Version 1.7 Food Count

import tkinter as tk
import random

class Ant:
    def __init__(self, canvas, x, y, size=5, speed=1):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.speed = speed
        self.direction = random.uniform(0, 2 * math.pi)
        self.food = False
        self.color = 'black'
        
        self.ant = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill=self.color
        )
        self.ant_brain(base1, food1)
        
    def ant_brain(self, _base, _food):
        dx = self.speed * math.cos(self.direction)
        dy = self.speed * math.sin(self.direction)
        self.x += dx
        self.y += dy
        
        # Boundaries checking
        if self.x < self.size:
            self.direction = random.uniform(-math.pi/2, math.pi/2)
            self.x = self.size
        elif self.x > c_width:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.x = c_width
        if self.y < self.size:
            self.direction = random.uniform(0, math.pi)
            self.y = self.size
        elif self.y > c_height:
            self.direction = random.uniform(math.pi, 2*math.pi)
            self.y = c_height 
        self.direction += random.uniform(-0.1, 0.1)
        
        # # Food area checking
        
        # Food Source
        if self.x > 380 and self.y > 380 and self.x < 420 and self.y < 420:
            self.food = True
            self.color = 'red'
            _food.update_value(self.ant)
            
        # Base
        elif self.x > 50 and self.x < 150 and self.y > 50 and self.y < 150:
            self.food = False
            self.color = 'black'
        
        self.update_position()

    def update_position(self):
        self.canvas.itemconfig(self.ant, fill=self.color)
        self.canvas.coords(
            self.ant,
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.canvas.after(10, self.ant_brain(base1, food1))
        
class AntBase:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        
        self.antBase = self.canvas.create_rectangle(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size,
            fill='white'
        )
        
        self.text = self.canvas.create_text(x, y, text=str(value))

    def update_value(self):
        self.value += 1 
        self.canvas.itemconfig(self.text, text=str(self.value))
        
class FoodSource:
    def __init__(self, canvas, x, y, size, value):
        self.canvas = canvas
        self.x, self.y = x, y
        self.size = size
        self.value = value
        self.food = self.canvas.create_oval(
            self.x - self.size, self.y - self.size,
            self.x + self.size, self.y + self.size
        )
        
        self.text = self.canvas.create_text(x, y, text = str(value))
    
    def update_value(self, _ant):
        self.value -= 1
        self.canvas.itemconfig(self.text, text, text=str(self.value))
        
        update_position()
        
# Canvas 
c_width = 500
c_height = 500

# Define Canvas
root = tk.Tk()
canvas = tk.Canvas(root, width=c_width, height=c_height)
canvas.pack()

base1 = AntBase(canvas, 100, 100, 50, 0)
food1 = FoodSource(canvas, 400, 400, 20, 100)

ants = []
for i in range(10):
    ant = Ant(canvas, 100, 100)
    ants.append(ant)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /var/folders/m7/zdxv2v7533n6g6x152zvnktm0000gn/T/ipykernel_52677/1678148273.py in <module>
#     119 ants = []
#     120 for i in range(10):
# --> 121     ant = Ant(canvas, 100, 100)
#     122     ants.append(ant)
#     123
#
# /var/folders/m7/zdxv2v7533n6g6x152zvnktm0000gn/T/ipykernel_52677/1678148273.py in __init__(self, canvas, x, y, size, speed)
#      19             fill=self.color
#      20         )
# ---> 21         self.ant_brain(base1, food1)
#      22
#      23     def ant_brain(self, _base, _food):
#
# /var/folders/m7/zdxv2v7533n6g6x152zvnktm0000gn/T/ipykernel_52677/1678148273.py in ant_brain(self, _base, _food)
#      55             self.color = 'black'
#      56
# ---> 57         self.update_position()
#      58
#      59     def update_position(self):
#
# /var/folders/m7/zdxv2v7533n6g6x152zvnktm0000gn/T/ipykernel_52677/1678148273.py in update_position(self)
#      65         )
#      66
# ---> 67         self.canvas.after(10, self.ant_brain(base1, food1))
#      68
#      69 class AntBase:
#
# ... last 2 frames repeated, from the frame below ...
#
# /var/folders/m7/zdxv2v7533n6g6x152zvnktm0000gn/T/ipykernel_52677/1678148273.py in ant_brain(self, _base, _food)
#      55             self.color = 'black'
#      56
# ---> 57         self.update_position()
#      58
#      59     def update_position(self):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
